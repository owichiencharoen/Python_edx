# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_style('whitegrid')
import datetime as datetime
import calendar

# %%
IBMdf = pd.read_csv('IBMStock.csv')
GEdf = pd.read_csv('GEStock.csv')
ProcterGambledf = pd.read_csv('ProcterGambleStock.csv')
Cocacoladf = pd.read_csv('CocacolaStock.csv')
Boeingdf = pd.read_csv('BoeingStock.csv')

IBMdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 2 columns):
# Date          480 non-null object
# StockPrice    480 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 7.6+ KB

# %%
IBMdf.head()
# Out:
#      Date  StockPrice
# 0  1/1/70  360.319048
# 1  2/1/70  346.723684
# 2  3/1/70  327.345714
# 3  4/1/70  319.852727
# 4  5/1/70  270.375238

# %%
IBMdf['StockPrice'].mean()
# Out:
# 144.3750303076664

# %%
GEdf.describe()
# Out:
#        StockPrice
# count  480.000000
# mean    59.303504
# std     23.992551
# min      9.293636
# 25%     44.214405
# 50%     55.812045
# 75%     72.226201
# max    156.843684

# %%
Cocacoladf.describe()
# Out:
#        StockPrice
# count  480.000000
# mean    60.029730
# std     25.166291
# min     30.057143
# 25%     42.755595
# 50%     51.436988
# 75%     69.617192
# max    146.584286

# %%
Boeingdf['StockPrice'].median()
# Out:
# 44.88339827

# %%
ProcterGambledf.describe()
# Out:
#        StockPrice
# count  480.000000
# mean    77.704516
# std     18.194140
# min     46.884545
# 25%     62.478663
# 50%     78.336077
# 75%     89.468375
# max    149.620000

# %%
Cocacoladf.set_index('Date').plot(legend=True,figsize=(10,4))

# %%
ProcterGambledf.set_index('Date').plot(legend=True,figsize=(10,4))

# %%
plt.plot(Cocacoladf.index,Cocacoladf['StockPrice'])
plt.plot(ProcterGambledf.index,ProcterGambledf['StockPrice'])
plt.plot(GEdf.index,GEdf['StockPrice'])
plt.plot(Boeingdf.index,Boeingdf['StockPrice'])
plt.plot(IBMdf.index,IBMdf['StockPrice'])

labels = ['Coke','PG','GE','Boeing','IBM']
plt.legend(labels, ncol=5, loc='upper center', 
           bbox_to_anchor=[0.5, 1.1], 
           columnspacing=1.0, labelspacing=0.0,
           handletextpad=0.0, handlelength=1.5,
           fancybox=True, shadow=True)

plt.show()
